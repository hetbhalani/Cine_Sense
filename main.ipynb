# %%
import pandas as pd
from datasets import Dataset

df = pd.read_csv('sentiment_dataset.csv')
dataset = Dataset.from_pandas(df[["review", "label"]])

# %%
from transformers import DistilBertTokenizerFast

tokenizer = DistilBertTokenizerFast.from_pretrained("distilbert-base-uncased")

def tokenize(batch):
    return tokenizer(batch["review"], padding="max_length", truncation=True)

dataset = dataset.map(tokenize, batched=True)
dataset = dataset.train_test_split(test_size=0.2)
# Out:
# Map: 100%|██████████| 2280/2280 [00:01<00:00, 1497.23 examples/s]

# %%
from transformers import DistilBertForSequenceClassification

model = DistilBertForSequenceClassification.from_pretrained(
    "distilbert-base-uncased",
    num_labels=3
)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import Trainer, TrainingArguments
import os

training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
)

from sklearn.metrics import accuracy_score, f1_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    return {
        "accuracy": accuracy_score(labels, preds),
        "f1": f1_score(labels, preds, average="weighted")
    }

os.environ["WANDB_DISABLED"] = "true"

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12184\1103424978.py:26: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x000001E9A3BAD390>>
# Traceback (most recent call last):
#   File "e:\CineSense\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 781, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 35
#      24 os.environ["WANDB_DISABLED"] = "true"
#      26 trainer = Trainer(
#      27     model=model,
#      28     args=training_args,
#    (...)     32     compute_metrics=compute_metrics,
#      33 )
# ---> 35 trainer.train()
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\trainer.py:2328, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2326         hf_hub_utils.enable_progress_bars()
#    2327 else:
# -> 2328     return inner_training_loop(
#    2329         args=args,
#    2330         resume_from_checkpoint=resume_from_checkpoint,
#    2331         trial=trial,
#    2332         ignore_keys_for_eval=ignore_keys_for_eval,
#    2333     )
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\trainer.py:2672, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2665 context = (
#    2666     functools.partial(self.accelerator.no_sync, model=model)
#    2667     if i != len(batch_samples) - 1
#    2668     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2669     else contextlib.nullcontext
#    2670 )
#    2671 with context():
# -> 2672     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2674 if (
#    2675     args.logging_nan_inf_filter
#    2676     and not is_torch_xla_available()
#    2677     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2678 ):
#    2679     # if loss is nan or inf simply add the average of previous logged losses
#    2680     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\trainer.py:4009, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    4006     return loss_mb.reduce_mean().detach().to(self.args.device)
#    4008 with self.compute_loss_context_manager():
# -> 4009     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    4011 del inputs
#    4012 if (
#    4013     self.args.torch_empty_cache_steps is not None
#    4014     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    4015 ):
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\trainer.py:4099, in Trainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    4097         kwargs["num_items_in_batch"] = num_items_in_batch
#    4098     inputs = {**inputs, **kwargs}
# -> 4099 outputs = model(**inputs)
#    4100 # Save past state if it exists
#    4101 # TODO: this needs to be fixed and made cleaner later.
#    4102 if self.args.past_index >= 0:
#
# File e:\CineSense\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File e:\CineSense\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:907, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     899 r"""
#     900 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     901     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     902     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     903     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     904 """
#     905 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 907 distilbert_output = self.distilbert(
#     908     input_ids=input_ids,
#     909     attention_mask=attention_mask,
#     910     head_mask=head_mask,
#     911     inputs_embeds=inputs_embeds,
#     912     output_attentions=output_attentions,
#     913     output_hidden_states=output_hidden_states,
#     914     return_dict=return_dict,
#     915 )
#     916 hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     917 pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File e:\CineSense\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File e:\CineSense\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:726, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     721     if self._use_sdpa and head_mask_is_none and not output_attentions:
#     722         attention_mask = _prepare_4d_attention_mask_for_sdpa(
#     723             attention_mask, embeddings.dtype, tgt_len=input_shape[1]
#     724         )
# --> 726 return self.transformer(
#     727     x=embeddings,
#     728     attn_mask=attention_mask,
#     729     head_mask=head_mask,
#     730     output_attentions=output_attentions,
#     731     output_hidden_states=output_hidden_states,
#     732     return_dict=return_dict,
#     733 )
#
# File e:\CineSense\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File e:\CineSense\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:531, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     528 if output_hidden_states:
#     529     all_hidden_states = all_hidden_states + (hidden_state,)
# --> 531 layer_outputs = layer_module(
#     532     hidden_state,
#     533     attn_mask,
#     534     head_mask[i],
#     535     output_attentions,
#     536 )
#     538 hidden_state = layer_outputs[-1]
#     540 if output_attentions:
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File e:\CineSense\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File e:\CineSense\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:466, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     456 """
#     457 Parameters:
#     458     x: torch.tensor(bs, seq_length, dim)
#    (...)    463     torch.tensor(bs, seq_length, dim) The output of the transformer block contextualization.
#     464 """
#     465 # Self-Attention
# --> 466 sa_output = self.attention(
#     467     query=x,
#     468     key=x,
#     469     value=x,
#     470     mask=attn_mask,
#     471     head_mask=head_mask,
#     472     output_attentions=output_attentions,
#     473 )
#     474 if output_attentions:
#     475     sa_output, sa_weights = sa_output  # (bs, seq_length, dim), (bs, n_heads, seq_length, seq_length)
#
# File e:\CineSense\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File e:\CineSense\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:392, in DistilBertSdpaAttention.forward(self, query, key, value, mask, head_mask, output_attentions)
#     389 k = shape(self.k_lin(key))  # (bs, n_heads, k_length, dim_per_head)
#     390 v = shape(self.v_lin(value))  # (bs, n_heads, k_length, dim_per_head)
# --> 392 attn_output = torch.nn.functional.scaled_dot_product_attention(
#     393     q,
#     394     k,
#     395     v,
#     396     attn_mask=mask,
#     397     dropout_p=self.dropout_prob if self.training else 0.0,
#     398     is_causal=False,
#     399 )
#     401 attn_output = unshape(attn_output)
#     402 attn_output = self.out_lin(attn_output)
#
# KeyboardInterrupt:

# %%
trainer.save_model("sentiment_model")

# Inference
from transformers import pipeline
sentiment_pipeline = pipeline("text-classification", model="./sentiment_model")

print(sentiment_pipeline("This movie was amazing! The visuals were stunning."))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 trainer.save_model("sentiment_model")
#       3 # Inference
#       4 from transformers import pipeline
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\trainer.py:4207, in Trainer.save_model(self, output_dir, _internal_call)
#    4204         self.model_wrapped.save_checkpoint(output_dir)
#    4206 elif self.args.should_save:
# -> 4207     self._save(output_dir)
#    4209 # Push to the Hub when `save_model` is called by the user.
#    4210 if self.args.push_to_hub and not _internal_call:
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\trainer.py:4311, in Trainer._save(self, output_dir, state_dict)
#    4309             torch.save(state_dict, os.path.join(output_dir, WEIGHTS_NAME))
#    4310 else:
# -> 4311     self.model.save_pretrained(
#    4312         output_dir, state_dict=state_dict, safe_serialization=self.args.save_safetensors
#    4313     )
#    4315 if self.processing_class is not None:
#    4316     self.processing_class.save_pretrained(output_dir)
#
# File e:\CineSense\.venv\Lib\site-packages\transformers\modeling_utils.py:4289, in PreTrainedModel.save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    4284     gc.collect()
#    4286 if safe_serialization:
#    4287     # At some point we will need to deal better with save_function (used for TPU and other distributed
#    4288     # joyfulness), but for now this enough.
# -> 4289     safe_save_file(shard, os.path.join(save_directory, shard_file), metadata={"format": "pt"})
#    4290 else:
#    4291     save_function(shard, os.path.join(save_directory, shard_file))
#
# File e:\CineSense\.venv\Lib\site-packages\safetensors\torch.py:352, in save_file(tensors, filename, metadata)
#     321 def save_file(
#     322     tensors: Dict[str, torch.Tensor],
#     323     filename: Union[str, os.PathLike],
#     324     metadata: Optional[Dict[str, str]] = None,
#     325 ):
#     326     """
#     327     Saves a dictionary of tensors into raw bytes in safetensors format.
#     328
#    (...)    350     ```
#     351     """
# --> 352     serialize_file(_flatten(tensors), filename, metadata=metadata)
#
# File e:\CineSense\.venv\Lib\site-packages\safetensors\torch.py:585, in _flatten(tensors)
#     576 if failing:
#     577     raise RuntimeError(
#     578         f"""
#     579         Some tensors share memory, this will lead to duplicate memory on disk and potential differences when loading them again: {failing}.
#    (...)    582         """
#     583     )
# --> 585 return {
#     586     k: {
#     587         "dtype": str(v.dtype).split(".")[-1],
#     588         "shape": v.shape,
#     589         "data": _tobytes(v, k),
#     590     }
#     591     for k, v in tensors.items()
#     592 }
#
# File e:\CineSense\.venv\Lib\site-packages\safetensors\torch.py:585, in <dictcomp>(.0)
#     576 if failing:
#     577     raise RuntimeError(
#     578         f"""
#     579         Some tensors share memory, this will lead to duplicate memory on disk and potential differences when loading them again: {failing}.
#    (...)    582         """
#     583     )
# --> 585 return {
#     586     k: {
#     587         "dtype": str(v.dtype).split(".")[-1],
#     588         "shape": v.shape,
#     589         "data": _tobytes(v, k),
#     590     }
#     591     for k, v in tensors.items()
#     592 }
#
# KeyboardInterrupt:
